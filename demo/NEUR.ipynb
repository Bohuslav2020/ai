# %% [markdown]
# <a href="https://colab.research.google.com/github/Bohuslav2020/ai/blob/main/demo/NEUR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
# %matplotlib inline
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras import utils

# %%
# ділимо датасет

# %%
(x_train, y_train), (x_test,y_test) = fashion_mnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle_boot']

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.grid(False)

# %%
# Обробка данних

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.grid(False)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(x_train[i], cmap = plt.cm.binary)
  plt.xlabel(class_names[y_train[i]])

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(), loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x_train,y_train, epochs=12)
# Out:
# Epoch 1/12
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.7484 - accuracy: 0.7593
# Epoch 2/12
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.5163 - accuracy: 0.8245
# Epoch 3/12
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4709 - accuracy: 0.8384
# Epoch 4/12
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4451 - accuracy: 0.8464
# Epoch 5/12
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4269 - accuracy: 0.8523
# Epoch 6/12
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4119 - accuracy: 0.8580
# Epoch 7/12
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3997 - accuracy: 0.8621
# Epoch 8/12
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3884 - accuracy: 0.8649
# Epoch 9/12
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3807 - accuracy: 0.8672
# Epoch 10/12
# ...

# %%
test_loss, test_acc = model.evaluate(x_test,y_test)
print("test", test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3986 - accuracy: 0.8600
# test 0.8600000143051147

# %%
predictions = model.predict(x_train)
# Out:
# 1875/1875 [==============================] - 4s 2ms/step

# %%
predictions[0]
# Out:
# array([6.9280048e-09, 1.0873923e-09, 3.3525165e-09, 7.9739175e-09,
#        3.1871541e-09, 4.6636467e-04, 7.1411684e-08, 2.5678668e-03,
#        1.9507674e-05, 9.9694622e-01], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 9

# %%
y_train[0]
# Out:
# 9
